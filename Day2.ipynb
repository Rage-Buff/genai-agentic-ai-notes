# %% [markdown]
# <a href="https://colab.research.google.com/github/Rage-Buff/genai-agentic-ai-notes/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Conditional Programming

# %%
# if elif else
age = int(input('Enter your age '))

if age>= 18:
  print('You can vote')
else:
  print('Sorry! You cannot vote')
# Out:
# Enter your age 18
# You can vote

# %% [markdown]
# #Basic bank chatbot

# %%
print('Welcome to hara bhara bank customer portal')
print('='*100)
import random
name=input('Enter your name: ')
query=''' Select Your choice..
1. Balance Enquiry
2.Raise Complaint
3.Give Feedback
4.Connect Customer Care
5. Exit
'''
print('query')
choice=int(input('Choose option: '))
if choice==1:
    print(f'Your current balance is Rs. {random.randint(1000,5000)}')
elif choice==2:
  print('Sorry to hear that you faced problem')
  print('Enter your complaint')
  comp=input(':\n')
  print('We have received your complaint')
  cid= random.randint(100,999)
  print(f'Your complaint id is {cid}')

elif choice==3:
  feedback=int(input('Enter your rating(1-5)'))
  print(f'Thanks for rating us {"⭐"*feedback} stars')
elif choice==4:
  print('You can connect to our customer care at 📞+91 9897198971')
elif choice==5:
  print('Thank you for using our services')
else:
  print('❌Invalid choice❌')
# Out:
# Welcome to hara bhara bank customer portal
# ...
# Enter your name: me
# query
# Choose option: 1
# Your current balance is Rs. 1013

# %% [markdown]
# #Random Nuber guess Game

# %%
import random
print('Welcome to Random Number Guessing Game')
comp= random.randint(1,10)
try:
  user= int(input('Guess a number: '))
except:
  print('Invalid input')
else:
  if comp == user:
    print('😁You Won😁')
    print('My number was also',comp)
  else:
     print('🤦‍♂️You Lose🤦‍♂️')
     print('The number was' ,comp)
# Out:
# Welcome to Random Number Guessing Game
# Guess a number: 43
# 🤦‍♂️You Lose🤦‍♂️
# The number was 6

# %% [markdown]
# #Flow Control using Loops

# %%
#for loop & while loop
import time
msg = 'Hello Peter🐙'
for i in msg:
  print(i, end="")
  time.sleep(0.3)
# Out:
# Hello Peter🐙

# %% [markdown]
# #Random Password Generator

# %%
import random
import string
print('Welcome to Random Password Generator')
a = string.ascii_letters #a-z A-Z
b = string.digits #0-9
c = string.punctuation #special character

all_characters =a+b+c
length = 15 # You can change the desired length of the password here
password = ""

for i in range(length):
  password += random.choice(all_characters)

print('Generated Password: ',password)
# Out:
# Welcome to Random Password Generator
# Generated Password:  oRiwkw`G9]'|&yg

# %% [markdown]
# # Important Questions asked in interviews

# %%
#find common elements in the given to lists
s1 =[2,3,55,75,74,94,22]
s2 =[55,6,39,22]
common=[]#empty list named common

for i in s1: #Outer loop
  for j in s2: #Inner loop
    if i==j:
      common.append(i) #

print('Common Elements: ',common)
# Out:
# Common Elements:  [55, 22]

# %% [markdown]
# #To generate a QRcode in python

# %%
# !pip install qrcode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.6 MB/s eta 0:00:00
# ...

# %%
import qrcode
url="https://music.youtube.com/"
image = qrcode.make(url)
image.save("music_qr.jpeg")

from IPython import display
display.Image("music_qr.jpeg")
