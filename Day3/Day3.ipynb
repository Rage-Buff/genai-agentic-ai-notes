# %% [markdown]
# #ROCK ,PAPER ,SCISSORS Game

# %%
import random

# Game settings
player_score = 0
computer_score = 0
player_money = 0
computer_money = 0
entry_fees = 10
win_amount = 20
possible_choice = ['rock', 'paper', 'scissors']

print("--- Welcome to Best of 3: Rock, Paper, Scissors! ---")

# Run until either side wins 2 rounds
while player_score < 2 and computer_score < 2:
    computer_choice = random.choice(possible_choice)
    player_choice = input('\nSelect (rock/paper/scissors): ').lower()

    if player_choice not in possible_choice:
        print('Invalid choice, round skipped.')
        continue

    print('='*30)
    print(f'Computer: {computer_choice} | You: {player_choice}')
    print('='*30)

    # Determine Winner of the Round
    if player_choice == computer_choice:
        print('Result: MATCH DRAW')

    elif (player_choice == 'rock' and computer_choice == 'paper') or \
         (player_choice == 'paper' and computer_choice == 'scissors') or \
         (player_choice == 'scissors' and computer_choice == 'rock'):
        print('Result: Computer wins this round! ☹️')
        computer_score += 1
        computer_money += entry_fees
        player_money -= entry_fees
    else:
        print('Result: You win this round! 😊')
        player_score += 1
        player_money += win_amount
        computer_money -= win_amount

    print(f'Score: You {player_score} - {computer_score} Computer')

# Final Results
print('\n' + '='*30)
if player_score == 2:
    print('Congratulations! You won the Best of 3!')
else:
    print('Game Over! The computer won the Best of 3.')

print(f'Final Money - You: {player_money} | Computer: {computer_money}')
print('='*30)
# Out:
# --- Welcome to Best of 3: Rock, Paper, Scissors! ---
#
# Select (rock/paper/scissors): paper
# ==============================
# Computer: rock | You: paper
# ==============================
# Result: You win this round! 😊
# Score: You 1 - 0 Computer
#
# Select (rock/paper/scissors): paper
# ==============================
# Computer: paper | You: paper
# ==============================
# Result: MATCH DRAW
# Score: You 1 - 0 Computer
#
# Select (rock/paper/scissors): scissors
# ==============================
# Computer: paper | You: scissors
# ==============================
# Result: You win this round! 😊
# Score: You 2 - 0 Computer
#
# ==============================
# Congratulations! You won the Best of 3!
# Final Money - You: 40 | Computer: -40
# ==============================

# %% [markdown]
# #Pattern Printing in python

# %%
name = input('Enter your name: ').upper()
length = len(name)

for i in range(length): # name Length loop
    for j in range(length-i): # space length loop
        print(" ",end="")

    for k in range(i+1): # value print loop
        print(name[k],end = " ")
    print()
# Out:
# Enter your name: mehul
#      M
#     M E
#    M E H
#   M E H U
#  M E H U L

# %%
import time
counter = 0
while counter <= 10:
    print(f'Hello, I am learning python {counter}')
    counter += 1
    time.sleep(0.5)
# Out:
# Hello, I am learning python 0
# Hello, I am learning python 1
# Hello, I am learning python 2
# Hello, I am learning python 3
# Hello, I am learning python 4
# Hello, I am learning python 5
# Hello, I am learning python 6
# Hello, I am learning python 7
# Hello, I am learning python 8
# Hello, I am learning python 9
# Hello, I am learning python 10
