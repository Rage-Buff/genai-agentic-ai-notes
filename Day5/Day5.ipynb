# %% [markdown]
# #OOPS in Python

# %%
#object oriented programming
#class is a blueprint that help to
#create object using oops concept

#pillars:
#Encapsulation,
#Inheritance,
#Polymorphism,
#and Abstraction.

# %% [markdown]
# #Car starting program with GIF's

# %%
from IPython import display as show
class AUDI:
    # Class constructor
    def __init__(self, name, model):
        self.name = name
        self.color = "Black"
        self.model = model
        self.engine = "V8"
        print("Audi car Object Created Successfully!")

    def engine_start(self):
        print("ENGINE START")


        # URL of the GIF image
        url = "https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExaHVodGh4YTdkZW9vcGN4YzZjZG5qcHVuNmViNHh5M3g4NXE0M2lpaSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/flbcUFdLSHwZC03p11/giphy.gif"

        show.display(show.Image(url=url, width=500))
    def turbo_boost_activate(self):
        print("TURBO BOOST ACTIVATED")

        url="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExcHZ0amRqZW1pbzAzcmxvN2E4MDNidmxyYmYzdWNjOXUxdXI1MzY0eCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/lUz4hKXENtMTgLn9si/giphy.gif"
        show.display(show.Image(url=url, width=500))

    def drift(self):
        print("DRIFTING")
        url="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExbGRnam9vZ2YwbW1hN2JyczFuYnVvdXBtbDkyZGV4Y3RlODVxNjhraSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/o6S51npJYQM48/giphy.gif"
        show.display(show.Image(url=url, width=500))
    def auto_park(self):
        print("AUTO PARK ACTIVATED")
        url="https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExMDFvODYxNDdzaHFjcWI2dDZic3g3MWQwanlvb3MzdWFoN250ZnFzdSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/tjQZgALoKlbR6/giphy.gif"
        show.display(show.Image(url=url, width=500))
Audi_car = AUDI("Audi", "R8")

Audi_car.engine_start()
Audi_car.turbo_boost_activate()
Audi_car.drift()
Audi_car.auto_park()
# Out:
# Audi car Object Created Successfully!
# ENGINE START
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExaHVodGh4YTdkZW9vcGN4YzZjZG5qcHVuNmViNHh5M3g4NXE0M2lpaSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/flbcUFdLSHwZC03p11/giphy.gif" width="500"/>
# TURBO BOOST ACTIVATED
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExcHZ0amRqZW1pbzAzcmxvN2E4MDNidmxyYmYzdWNjOXUxdXI1MzY0eCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/lUz4hKXENtMTgLn9si/giphy.gif" width="500"/>
# DRIFTING
# <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExbGRnam9vZ2YwbW1hN2JyczFuYnVvdXBtbDkyZGV4Y3RlODVxNjhraSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/o6S51npJYQM48/giphy.gif" width="500"/>
# AUTO PARK ACTIVATED
# <img src="https://media0.giphy.com/media/v1.Y2lkPTc5MGI3NjExMDFvODYxNDdzaHFjcWI2dDZic3g3MWQwanlvb3MzdWFoN250ZnFzdSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/tjQZgALoKlbR6/giphy.gif" width="500"/>

# %%
#Encapsulation
#Hide Sensitive Data
#bind attributes or methods
#can get using access modifier
#Public, Private ,Protected
# no underscore means public
# _ single underscore mens protected
# __ double underscore means private

# %% [markdown]
# #ATM Simulation using OOP

# %%
# Encapsulation using ATM class

class ATM:
  def __init__(self, bank_name):
    print(f"Welcome to {bank_name}Bank 🏦")
    self.bank_name =bank_name #Public
    self.__pin="0000" #Private
    self.__balance=2000 #Protected

  #class methods
  def __ask_pin(self): #Private method
      import getpass
      pin= getpass.getpass("Enter your 4 digit PIN: ")

      if pin ==self.__pin:
        return True
      else:
        return False
  def check_balance(self):
    if self.__ask_pin():
      print(f"Your Current balance is ₹{self.__balance}")
    else:
      print("Invalid PIN")

  def withdraw_amount(self):
    if self.__ask_pin():
      amount=int(input("Enter the amount you want to withdraw: "))
      if 0<amount<=self.__balance:
        print(f"AMount ₹{amount} withdrawl successfull")
        self.__balance-=amount
      else:
        print("Insufficient Balance")
    else:
      print("Invalid PIN")
  def change_pin(self):
    if self.__ask_pin():
      old_pin = input("Enter your old PIN: ")
      if old_pin == self.__pin:
        new_pin = input("Create your new PIN: ")
        pin_again= input("Enter again: ")
        if new_pin == pin_again:
          print("PIN changed successfully")
          self.__pin = new_pin
        else:
          print("PIN does not match")
      else:
        print("Invalid PIN")
    else:
      print("Invalid PIN")

#ATM object
sbi=ATM("SBI")

# ATM Menu
while True:
    print("\n===== ATM MENU =====")
    print("1. Check Balance")
    print("2. Withdraw Amount")
    print("3. Change PIN")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        sbi.check_balance()

    elif choice == "2":
        sbi.withdraw_amount()

    elif choice == "3":
        sbi.change_pin()

    elif choice == "4":
        print("Thank you for using SBI ATM!")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# Welcome to SBIBank 🏦
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Withdraw Amount
# 3. Change PIN
# 4. Exit
# Enter your choice: 1
# Enter your 4 digit PIN: ··········
# Your Current balance is ₹2000
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Withdraw Amount
# 3. Change PIN
# 4. Exit
# Enter your choice: 3
# Enter your 4 digit PIN: ··········
# Enter your old PIN: 0000
# Create your new PIN: 9999
# Enter again: 9999
# PIN changed successfully
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Withdraw Amount
# 3. Change PIN
# 4. Exit
# Enter your choice: 2
# Enter your 4 digit PIN: ··········
# Enter the amount you want to withdraw: 500
# AMount ₹500 withdrawl successfull
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Withdraw Amount
# 3. Change PIN
# 4. Exit
# Enter your choice: 1
# Enter your 4 digit PIN: ··········
# Your Current balance is ₹1500
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Withdraw Amount
# 3. Change PIN
# 4. Exit
# Enter your choice: 4
# ...
